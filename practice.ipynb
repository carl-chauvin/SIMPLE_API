# %%
from pandas import pandas
import pandas as pd

# %%
pip install pyfetch

# %%
path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"

await download(path, "auto.csv")
path="auto.csv"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Easy Speech-to-Text with Python Project\practice.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/c%3A/Easy%20Speech-to-Text%20with%20Python%20Project/practice.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
# ----> <a href='vscode-notebook-cell:/c%3A/Easy%20Speech-to-Text%20with%20Python%20Project/practice.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> await download(path, "auto.csv")
#       <a href='vscode-notebook-cell:/c%3A/Easy%20Speech-to-Text%20with%20Python%20Project/practice.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> path="auto.csv"
#
# NameError: name 'download' is not defined
