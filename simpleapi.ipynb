# %%
pip install randomuser
# Out:
# Collecting randomuserNote: you may need to restart the kernel to use updated packages.
#
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (pyproject.toml): started
#   Building wheel for randomuser (pyproject.toml): finished with status 'done'
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5092 sha256=86c96d970f2838266b825198e03573a2465d126849e85ae68b2bf204cce05e0e
#   Stored in directory: c:\users\nandy\appdata\local\pip\cache\wheels\fc\8d\74\bcdd5e8a9433bfa4c4f9c1cccbfec40139322a28d77f61e45e
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from randomuser import RandomUser

# %%
pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading pandas-2.0.3-cp311-cp311-win_amd64.whl (10.6 MB)
#                                               0.0/10.6 MB ? eta -:--:--
#                                              0.0/10.6 MB 660.6 kB/s eta 0:00:17
#                                              0.0/10.6 MB 393.8 kB/s eta 0:00:27
#                                              0.1/10.6 MB 731.4 kB/s eta 0:00:15
#                                              0.2/10.6 MB 876.1 kB/s eta 0:00:12
#                                               0.2/10.6 MB 1.0 MB/s eta 0:00:11
#      -                                        0.4/10.6 MB 1.4 MB/s eta 0:00:08
#      -                                        0.5/10.6 MB 1.6 MB/s eta 0:00:07
#      --                                       0.8/10.6 MB 2.1 MB/s eta 0:00:05
#      ---                                      1.0/10.6 MB 2.6 MB/s eta 0:00:04
#      -----                                    1.5/10.6 MB 3.1 MB/s eta 0:00:03
#      -------                                  2.1/10.6 MB 4.0 MB/s eta 0:00:03
#      ---------                                2.6/10.6 MB 4.5 MB/s eta 0:00:02
#      --------------                           3.8/10.6 MB 6.4 MB/s eta 0:00:02
#      ----------------                         4.4/10.6 MB 6.6 MB/s eta 0:00:01
#      ----------------------                   5.9/10.6 MB 8.4 MB/s eta 0:00:01
#      ------------------------                 6.5/10.6 MB 8.6 MB/s eta 0:00:01
#      ------------------------------           8.1/10.6 MB 10.2 MB/s eta 0:00:01
#      ------------------------------------     9.7/10.6 MB 11.5 MB/s eta 0:00:01
#      --------------------------------------  10.6/10.6 MB 17.2 MB/s eta 0:00:01
#      --------------------------------------- 10.6/10.6 MB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nandy\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#                                               0.0/502.3 kB ? eta -:--:--
#      ------------------------------------- 502.3/502.3 kB 32.8 MB/s eta 0:00:00
# Collecting tzdata>=2022.1 (from pandas)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#                                               0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 20.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in c:\users\nandy\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: six>=1.5 in c:\users\nandy\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.0.3 pytz-2023.3 tzdata-2023.3

# %%
from randomuser import RandomUser
from pandas import pandas
r = RandomUser()
some_list = r.generate_users(10)
some_list

name = r.get_full_name()
for user in some_list:
    print (user.get_full_name()," ",user.get_email(), user.get_nat(), user.get_picture())
# Out:
# Buse Kunt   buse.kunt@example.com TR https://randomuser.me/api/portraits/women/9.jpg
# Livia Lambert   livia.lambert@example.com CH https://randomuser.me/api/portraits/women/22.jpg
# Ricardo Gil   ricardo.gil@example.com ES https://randomuser.me/api/portraits/men/10.jpg
# Matilda Ramo   matilda.ramo@example.com FI https://randomuser.me/api/portraits/women/96.jpg
# Joann Hernandez   joann.hernandez@example.com US https://randomuser.me/api/portraits/women/91.jpg
# Nico Hjorth   nico.hjorth@example.com NO https://randomuser.me/api/portraits/men/44.jpg
# Denise Cox   denise.cox@example.com AU https://randomuser.me/api/portraits/women/9.jpg
# Ege Duygulu   ege.duygulu@example.com TR https://randomuser.me/api/portraits/men/26.jpg
# Sophia Johnson   sophia.johnson@example.com CA https://randomuser.me/api/portraits/women/74.jpg
# Olive Morris   olive.morris@example.com NZ https://randomuser.me/api/portraits/women/22.jpg

# %%
from randomuser import RandomUser
from pandas import pandas
r = RandomUser()
some_list = r.generate_users(10)
some_list

name = r.get_full_name()

def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pandas.DataFrame(users) 

get_users()
df1 = pandas.DataFrame(get_users())
